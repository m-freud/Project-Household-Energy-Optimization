# %% [markdown]
# # Household Plotter
# plot households

# %%
# paste this to enable src. imports

from pathlib import Path
import sys

# find the repository root that contains 'src'
repo_root = next((p for p in Path.cwd().resolve().parents if (p / "src").exists()), "")
sys.path.insert(0, str(repo_root))

# %%
from src.config import Config
print(Config.ROOT_DIR)
# Out:
# C:\Users\maxfr\Desktop\Project Household Energy Optimization

# %%
# start a simulation
from src.simulation.main import init_simulation

simulation = init_simulation()
household_1 = simulation.create_household(1)

# %%
print(household_1.has_bess)
# Out:
# True

# %%
from src.simulation.policies.blind import no_control
from src.simulation.policies.greedy import advanced_ev_bess, basic_bess

# simulation.run_household(1, policy=no_control, start_time=0)
simulation.run_household(1, policy=basic_bess, start_time=0)
# Out:
# running household 1 with policy basic_bess

# %%
from src.analysis.plotting.household_plotter import plot_household


fields = ["load", "pv_gen", "bess_power", "ev1_power"]


fig = plot_household(
    household_id=1,
    policy="basic_bess",
    fields=fields,
    colors={"load": "blue", "pv_gen": "orange", "bess_power": "green", "ev1_power": "red"},
    title="Household 1: Load and PV Generation",
)

# %%
fields = ["load", "pv_gen", "bess_power", "ev1_power"]

for i in range(1, 20):
    simulation.run_household(i, policy=advanced_ev_bess, start_time=0)

    fig = plot_household(
        household_id=i,
        policy="advanced_ev_bess",
        fields=fields,
        colors={"load": "blue", "pv_gen": "orange", "bess_power": "green", "ev1_power": "red"},
        title=f"Household {i}: Load and PV Generation",
    )
# Out:
# running household 1 with policy advanced_ev_bess
# running household 2 with policy advanced_ev_bess
# running household 3 with policy advanced_ev_bess
# running household 4 with policy advanced_ev_bess
# running household 5 with policy advanced_ev_bess
# running household 6 with policy advanced_ev_bess
# running household 7 with policy advanced_ev_bess
# running household 8 with policy advanced_ev_bess
# running household 9 with policy advanced_ev_bess
# running household 10 with policy advanced_ev_bess
# running household 11 with policy advanced_ev_bess
# running household 12 with policy advanced_ev_bess
# running household 13 with policy advanced_ev_bess
# running household 14 with policy advanced_ev_bess
# running household 15 with policy advanced_ev_bess
# running household 16 with policy advanced_ev_bess
# running household 17 with policy advanced_ev_bess
# running household 18 with policy advanced_ev_bess
# running household 19 with policy advanced_ev_bess
