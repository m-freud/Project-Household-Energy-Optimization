# %% [markdown]
# # Household Plotter
# plot households

# %%
# paste this to enable src. imports

from pathlib import Path
import sys

# find the repository root that contains 'src'
repo_root = next((p for p in Path.cwd().resolve().parents if (p / "src").exists()), "")
sys.path.insert(0, str(repo_root))

# %%
from src.config import Config

# %%
# start a simulation
from src.simulation.main import init_simulation
from simulation.scenarios.scenario import default_scenario

simulation = init_simulation()

# %%
from simulation.policies.naive_linear_satisfaction import naive_linear_satisfaction, last_minute_satisfaction
from simulation.policies.basic_examples import no_control

# simulation.run_household(1, policy=no_control, start_time=0)
# simulation.run_household(1, policy=no_control, start_time=0)
simulation.run_household(1, policy=last_minute_satisfaction, start_time=0)
# Out:
# running household 1 with policy last_minute_satisfaction
# Set initial SOC of bess to 0.0 kWh which is 0.0% of capacity
# Set initial SOC of ev1 to 8.8 kWh which is 20.0% of capacity
# Set initial SOC of ev2 to 13.3 kWh which is 20.0% of capacity
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# File ~\Desktop\Project Household Energy Optimization\src\simulation\simulation.py:262, in Simulation.load_history_to_influx(self, household, policy_name, scenario_name, measurements)
#     261 try:
# --> 262     self.influx_write_api.write(
#     263         bucket=Config.INFLUX_BUCKET,
#     264         org=Config.INFLUX_ORG,
#     265         record=points
#     266     )
#     267 except Exception as e:
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\client\write_api.py:381, in WriteApi.write(self, bucket, org, record, write_precision, **kwargs)
#     379     return self._post_write(_async_req, bucket, org, final_string, payload[0])
# --> 381 results = list(map(write_payload, payloads.items()))
#     382 if not _async_req:
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\client\write_api.py:379, in WriteApi.write.<locals>.write_payload(payload)
#     378 final_string = b'\n'.join(payload[1])
# --> 379 return self._post_write(_async_req, bucket, org, final_string, payload[0])
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\client\write_api.py:516, in WriteApi._post_write(self, _async_req, bucket, org, body, precision, **kwargs)
#     514 def _post_write(self, _async_req, bucket, org, body, precision, **kwargs):
# --> 516     return self._write_service.post_write(org=org, bucket=bucket, body=body, precision=precision,
#     517                                           async_req=_async_req,
#     518                                           content_type="text/plain; charset=utf-8",
#     519                                           **kwargs)
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\service\write_service.py:60, in WriteService.post_write(self, org, bucket, body, **kwargs)
#      59 else:
# ---> 60     (data) = self.post_write_with_http_info(org, bucket, body, **kwargs)  # noqa: E501
#      61     return data
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\service\write_service.py:90, in WriteService.post_write_with_http_info(self, org, bucket, body, **kwargs)
#      87 local_var_params, path_params, query_params, header_params, body_params = \
#      88     self._post_write_prepare(org, bucket, body, **kwargs)  # noqa: E501
# ---> 90 return self.api_client.call_api(
#      91     '/api/v2/write', 'POST',
#      92     path_params,
#      93     query_params,
#      94     header_params,
#      95     body=body_params,
#      96     post_params=[],
#      97     files={},
#      98     response_type=None,  # noqa: E501
#      99     auth_settings=[],
#     100     async_req=local_var_params.get('async_req'),
#     101     _return_http_data_only=local_var_params.get('_return_http_data_only'),  # noqa: E501
#     102     _preload_content=local_var_params.get('_preload_content', True),
#     103     _request_timeout=local_var_params.get('_request_timeout'),
#     104     collection_formats={},
#     105     urlopen_kw=kwargs.get('urlopen_kw', None))
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\_sync\api_client.py:343, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     342 if not async_req:
# --> 343     return self.__call_api(resource_path, method,
#     344                            path_params, query_params, header_params,
#     345                            body, post_params, files,
#     346                            response_type, auth_settings,
#     347                            _return_http_data_only, collection_formats,
#     348                            _preload_content, _request_timeout, urlopen_kw)
#     349 else:
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\_sync\api_client.py:173, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     172 # perform request and return response
# --> 173 response_data = self.request(
#     174     method, url, query_params=query_params, headers=header_params,
#     175     post_params=post_params, body=body,
#     176     _preload_content=_preload_content,
#     177     _request_timeout=_request_timeout, **urlopen_kw)
#     179 self.last_response = response_data
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\_sync\api_client.py:388, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     387 elif method == "POST":
# --> 388     return self.rest_client.POST(url,
#     389                                  query_params=query_params,
#     390                                  headers=headers,
#     391                                  post_params=post_params,
#     392                                  _preload_content=_preload_content,
#     393                                  _request_timeout=_request_timeout,
#     394                                  body=body,
#     395                                  **urlopen_kw)
#     396 elif method == "PUT":
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\_sync\rest.py:311, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     310 """Perform POST HTTP request."""
# --> 311 return self.request("POST", url,
#     312                     headers=headers,
#     313                     query_params=query_params,
#     314                     post_params=post_params,
#     315                     _preload_content=_preload_content,
#     316                     _request_timeout=_request_timeout,
#     317                     body=body,
#     318                     **urlopen_kw)
#
# File c:\Users\maxfr\Desktop\Project Household Energy Optimization\.venv\Lib\site-packages\influxdb_client\_sync\rest.py:261, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout, **urlopen_kw)
#     260 if not 200 <= r.status <= 299:
# --> 261     raise ApiException(http_resp=r)
#     263 return r
#
# ApiException: (422)
# Reason: Unprocessable Entity
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'X-Influxdb-Build': 'OSS', 'X-Influxdb-Version': 'v2.7.12', 'X-Platform-Error-Code': 'unprocessable entity', 'Date': 'Tue, 27 Jan 2026 20:19:14 GMT', 'Content-Length': '224'})
# HTTP response body: {"code":"unprocessable entity","message":"failure writing points to database: partial write: field type conflict: input field \"value\" on measurement \"bess_power\" is type float, already exists as type integer dropped=16"}
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 6
#       2 from simulation.policies.basic_examples import no_control
#       4 # simulation.run_household(1, policy=no_control, start_time=0)
#       5 # simulation.run_household(1, policy=no_control, start_time=0)
# ----> 6 simulation.run_household(1, policy=last_minute_satisfaction, start_time=0)
#
# File ~\Desktop\Project Household Energy Optimization\src\simulation\simulation.py:80, in Simulation.run_household(self, player_id, policy, scenario, start_time)
#      77 for t in range(start_time, self.num_timesteps):
#      78     self.step(household, policy=policy, scenario=scenario, duration_hours=0.25, time=t)
# ---> 80 self.load_history_to_influx(household, policy_name=policy.__name__, scenario_name=scenario.name)
#      81 self.load_results_to_sqlite(household, policy_name=policy.__name__, scenario_name=scenario.name)
#      83 return household
#
# File ~\Desktop\Project Household Energy Optimization\src\simulation\simulation.py:268, in Simulation.load_history_to_influx(self, household, policy_name, scenario_name, measurements)
#     262     self.influx_write_api.write(
#     263         bucket=Config.INFLUX_BUCKET,
#     264         org=Config.INFLUX_ORG,
#     265         record=points
#     266     )
#     267 except Exception as e:
# --> 268     raise RuntimeError(f"Failed to write {len(points)} points to InfluxDB: {e}") from e
#
# RuntimeError: Failed to write 96 points to InfluxDB: (422)
# Reason: Unprocessable Entity
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'X-Influxdb-Build': 'OSS', 'X-Influxdb-Version': 'v2.7.12', 'X-Platform-Error-Code': 'unprocessable entity', 'Date': 'Tue, 27 Jan 2026 20:19:14 GMT', 'Content-Length': '224'})
# HTTP response body: {"code":"unprocessable entity","message":"failure writing points to database: partial write: field type conflict: input field \"value\" on measurement \"bess_power\" is type float, already exists as type integer dropped=16"}

# %%
from src.analysis.plotting.household_plotting import plot_household_fields
from simulation.scenarios.scenario import default_scenario
from simulation.policies.naive_linear_satisfaction import naive_linear_satisfaction, last_minute_satisfaction
from src.simulation.scenarios.scenario import default_scenario


fields = ["base_load", "pv_gen", "net_load", "bess_soc", "ev1_soc", "ev2_soc"]


fig = plot_household_fields(
    household_id=1,
    policy=no_control,
    scenario=default_scenario,
    fields=fields,
    title="Household 1: Load and PV Generation",
)

fig = plot_household_fields(
    household_id=1,
    policy=last_minute_satisfaction,
    scenario=default_scenario,
    fields=fields,
    title="Household 1: Load and PV Generation",
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 3
#       1 from src.analysis.plotting.household_plotter import plot_household_fields
#       2 from simulation.scenarios.scenario import default_scenario
# ----> 3 from simulation.policies.naive_linear_satisfaction import naive_linear_satisfaction, last_minute_satisfaction
#       4 from src.simulation.scenarios.scenario import default_scenario
#       7 fields = ["base_load", "pv_gen", "net_load", "bess_soc", "ev1_soc", "ev2_soc"]
#
# ImportError: cannot import name 'last_minute_satisfaction' from 'simulation.policies.naive_linear_satisfaction' (C:\Users\maxfr\Desktop\Project Household Energy Optimization\src\simulation\policies\naive_linear_satisfaction.py)
